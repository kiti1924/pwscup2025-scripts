# %%
import pandas as pd

# %%
input_b = pd.read_csv("in/CC22_1_ds_e1.0_k2.csv")
# a.to_csv("output.csv", index=False)
type(input_b)
input_b
# Out:
#      GENDER  AGE   RACE    ETHNICITY  encounter_count  num_procedures  \
# 0         F  100  white  nonhispanic               71             179
# 1         M   39  white  nonhispanic               29              83
# 2         F   28  white  nonhispanic               29              88
# 3         M   17  white  nonhispanic               25              90
# 4         M   82  white  nonhispanic               36             167
# ...     ...  ...    ...          ...              ...             ...
# 9995      M   80  white  nonhispanic               66             231
# 9996      F   21  white  nonhispanic               93             159
# 9997      M    4  white  nonhispanic               19              20
# 9998      F   59  white  nonhispanic               37             108
# 9999      M   45  white  nonhispanic               12              32
#
#       num_medications  num_immunizations  num_allergies  num_devices  \
# ...

# %%
input_c = pd.read_csv("in/CC22_1.csv")
# a.to_csv("output.csv", index=False)
type(input_c)
input_c
# Out:
#      GENDER  AGE      RACE    ETHNICITY  encounter_count  num_procedures  \
# 0         M   54     white  nonhispanic               39             119
# 1         M    8     white  nonhispanic               28               3
# 2         M   22     white  nonhispanic               51             109
# 3         M   34     white  nonhispanic               15              20
# 4         F   61     white  nonhispanic              769            1001
# ...     ...  ...       ...          ...              ...             ...
# 9995      M   98     white  nonhispanic               37             248
# 9996      F   64  hawaiian  nonhispanic               40             136
# 9997      M   89     white     hispanic               96             222
# 9998      F   49     white  nonhispanic               34              87
# 9999      M   36     white  nonhispanic               13              25
#
#       num_medications  num_immunizations  num_allergies  num_devices  \
# ...

# %%
input_c.columns[0]
# Out:
# Index(['GENDER', 'AGE', 'RACE', 'ETHNICITY', 'encounter_count',
#        'num_procedures', 'num_medications', 'num_immunizations',
#        'num_allergies', 'num_devices', 'asthma_flag', 'stroke_flag',
#        'obesity_flag', 'depression_flag', 'mean_systolic_bp',
#        'mean_diastolic_bp', 'mean_bmi', 'mean_weight'],
#       dtype='object')

# %%
input_c.dtypes
# Out:
# GENDER                object
# AGE                    int64
# RACE                  object
# ETHNICITY             object
# encounter_count        int64
# num_procedures         int64
# num_medications        int64
# num_immunizations      int64
# num_allergies          int64
# num_devices            int64
# asthma_flag            int64
# stroke_flag            int64
# obesity_flag           int64
# depression_flag        int64
# mean_systolic_bp     float64
# mean_diastolic_bp    float64
# mean_bmi             float64
# mean_weight          float64
# dtype: object

# %%
input_c.dtypes
for i in input_b.columns:
    input_c[i] = input_c[i].astype(input_b[i].dtype)
input_c
# Out:
#      GENDER  AGE      RACE    ETHNICITY  encounter_count  num_procedures  \
# 0         M   61     white  nonhispanic               43             131
# 1         F   60     other  nonhispanic              124             240
# 2         F   37     asian  nonhispanic              657             967
# 3         F   95     white  nonhispanic              810             647
# 4         F    5     white  nonhispanic              787             100
# ...     ...  ...       ...          ...              ...             ...
# 9995      F   45     other  nonhispanic               56             100
# 9996      M   82     white  nonhispanic               99             153
# 9997      M   20     white  nonhispanic               25             193
# 9998      F   32    native     hispanic               65            1697
# 9999      M   16  hawaiian  nonhispanic               40              64
#
#       num_medications  num_immunizations  num_allergies  num_devices  \
# ...
